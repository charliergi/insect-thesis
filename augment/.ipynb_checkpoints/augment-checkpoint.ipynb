# %% [markdown]
# # TLT Augment example usecase
#
# This notebook shows an example usecase of Augmenting an object detection dataset using `tlt-augment` in the Transfer Learning Toolkit.
#
# 0. [Set-up env variables](#head-0)
# 1. [Prepare the dataset](#head-1)
# 2. [Augment the dataset](#head-2)
# 3. [Visualize augmented results](#head-3)

# %% [markdown]
# ## 0. Set up env variables <a class="anchor" id="head-0"></a>
# This project sets up all the environment variables for the input dataset and the augmented output data.
#
# *Note: Please make sure to remove any stray artifacts/files from the `$USER_EXPERIMENT_DIR` or `$DATA_DOWNLOAD_DIR` paths as mentioned below, that may have been generated from previous runs.

# %%
# %env USER_EXPERIMENT_DIR=/workspace/tlt-experiments/insect-thesis/data/kitti
# %env DATA_DOWNLOAD_DIR=/workspace/tlt-experiments/insect-thesis/data/kitti
# %env SPECS_DIR=./specs
# Out:
# env: USER_EXPERIMENT_DIR=/workspace/tlt-experiments/insect-thesis
# env: DATA_DOWNLOAD_DIR=/workspace/tlt-experiments/insect-thesis/data/kitti
# env: SPECS_DIR=./specs

# %% [markdown]
# ## 1. Prepare the dataset <a class="anchor" id="head-1"></a>
#
# We will be using the kitti object detection dataset for this example. To find more details, please visit http://www.cvlibs.net/datasets/kitti/eval_object.php?obj_benchmark=2d. Please download both, the left color images of the object dataset from [here](http://www.cvlibs.net/download.php?file=data_object_image_2.zip) and, the training labels for the object dataset from [here](http://www.cvlibs.net/download.php?file=data_object_label_2.zip), and place the zip files in `$DATA_DOWNLOAD_DIR`
#
# The data will then be extracted to have
# * training images in `$DATA_DOWNLOAD_DIR/train/images`
# * training labels in `$DATA_DOWNLOAD_DIR/train/labels`
# * testing images in `$DATA_DOWNLOAD_DIR/inference/images`
#
# *Note: There are no labels for the testing images, therefore we use it just to visualize inferences for the trained model.*

# %%
# Check the dataset is present
# !mkdir -p $DATA_DOWNLOAD_DIR
#!if [ ! -f $DATA_DOWNLOAD_DIR/data_object_image_2.zip ]; then echo 'Image zip file not found, please download.'; else echo 'Found Image zip file.';fi
#!if [ ! -f $DATA_DOWNLOAD_DIR/data_object_label_2.zip ]; then echo 'Label zip file not found, please download.'; else echo 'Found Labels zip file.';fi

# %%
# unpack downloaded datasets to $DATA_DOWNLOAD_DIR.
# The training images will be under $DATA_DOWNLOAD_DIR/training/image_2 and 
# labels will be under $DATA_DOWNLOAD_DIR/training/label_2.
# The testing images will be under $DATA_DOWNLOAD_DIR/testing/image_2.
#!unzip -u $DATA_DOWNLOAD_DIR/data_object_image_2.zip -d $DATA_DOWNLOAD_DIR
#!unzip -u $DATA_DOWNLOAD_DIR/data_object_label_2.zip -d $DATA_DOWNLOAD_DIR

# %%
# verify
import os

DATA_DIR = os.path.join(DATA_DOWNLOAD_DIR,'geometridae')

num_train_images = len(os.listdir(os.path.join(DATA_DIR, "train/images")))
num_train_labels = len(os.listdir(os.path.join(DATA_DIR, "train/labels")))
num_inference_images = len(os.listdir(os.path.join(DATA_DIR, "inference/images")))
print("Number of images in the trainval set. {}".format(num_train_images))
print("Number of labels in the trainval set. {}".format(num_train_labels))
print("Number of images in the inference set. {}".format(num_inference_images))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-72875ac7ec57> in <module>
#       2 import os
#       3
# ----> 4 DATA_DIR = os.path.join(DATA_DOWNLOAD_DIR,'geometridae')
#       5
#       6 num_train_images = len(os.listdir(os.path.join(DATA_DIR, "train/images")))
#
# NameError: name 'DATA_DOWNLOAD_DIR' is not defined

# %%
# Sample kitti label.
# !cat $DATA_DOWNLOAD_DIR/train/images/1-geometridae.txt

# %% [markdown]
# ## Augment the dataset <a class="anchor" id="head-2"></a>
# This cell ingests the downloaded KITTI dataset and augments the dataset. For this use case we add
# 1. a spatial rotation of 10 degreess.
# 2. a color space hue rotation of 5 degrees.

# %%
# !cat $SPECS_DIR/default_spec.txt
# Out:
# # Spec file for tlt-augment.
# spatial_config{
#   rotation_config{
#       angle: 0.0
#       units: "degrees"
#   }
# }
# dataset_config{
#     image_path: "images"
#     label_path: "labels"
# }
# color_config{
#     hue_saturation_config{
#         hue_rotation_angle: 5.0
#         saturation_shift: 1.0
#     }
# }
# output_image_width: 1248
# output_image_height: 384
# output_image_channel: 3
# image_extension: ".jpg"

# %%
# !augment -a $SPECS_DIR/default_spec.txt \
         -o $DATA_DOWNLOAD_DIR/geometridae_augmented \
         -d $DATA_DOWNLOAD_DIR/geometridae/train
# Out:
# 2021-03-26 13:33:56.583909: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# Using TensorFlow backend.
# 2021-03-26 13:34:00,533 [INFO] iva.augment.spec_handler.spec_loader: Merging specification from ./specs/default_spec.txt
# 2021-03-26 13:34:00,533 [INFO] iva.augment.build_augmentor: Creating output directories.
# 2021-03-26 13:34:00,533 [INFO] iva.augment.build_augmentor: Input dataset: /workspace/tlt-experiments/insect-thesis/data/kitti/geometridae/train
# 2021-03-26 13:34:00,533 [INFO] iva.augment.build_augmentor: Output dataset: /workspace/tlt-experiments/insect-thesis/data/kitti/geometridae_augmented
# 2021-03-26 13:34:00.543315: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-26 13:34:00.590862: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1082] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-26 13:34:00.591353: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1665] Found device 0 with properties:
# name: GeForce RTX 3060 Ti major: 8 minor: 6 memoryClockRate(GHz): 1.695
# pciBusID: 0000:01:00.0
# 2021-03-26 13:34:00.591393: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-03-26 13:34:00.611458: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-03-26 13:34:00.620305: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-03-26 13:34:00.624037: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-03-26 13:34:00.644768: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.11
# 2021-03-26 13:34:00.649725: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-03-26 13:34:00.649870: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-03-26 13:34:00.649953: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1082] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-26 13:34:00.650345: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1082] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-26 13:34:00.650664: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1793] Adding visible gpu devices: 0
# 2021-03-26 13:34:00.651253: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-03-26 13:34:02.251105: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1206] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-03-26 13:34:02.251137: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212]      0
# 2021-03-26 13:34:02.251143: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1225] 0:   N
# 2021-03-26 13:34:02.251283: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1082] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-26 13:34:02.252474: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1082] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-26 13:34:02.252867: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1082] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-26 13:34:02.253299: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1351] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 5675 MB memory) -> physical GPU (device: 0, name: GeForce RTX 3060 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6)
# 2021-03-26 13:34:02,264 [INFO] iva.augment.build_augmentor: Constructed the augmentor pipeline.
# WARNING:tensorflow:From /home/vpraveen/.cache/dazel/_dazel_vpraveen/216c8b41e526c3295d3b802489ac2034/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/common/graph/initializers.py:14: The name tf.local_variables_initializer is deprecated. Please use tf.compat.v1.local_variables_initializer instead.
#
# 2021-03-26 13:34:02,324 [WARNING] tensorflow: From /home/vpraveen/.cache/dazel/_dazel_vpraveen/216c8b41e526c3295d3b802489ac2034/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/common/graph/initializers.py:14: The name tf.local_variables_initializer is deprecated. Please use tf.compat.v1.local_variables_initializer instead.
#
# WARNING:tensorflow:From /home/vpraveen/.cache/dazel/_dazel_vpraveen/216c8b41e526c3295d3b802489ac2034/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/common/graph/initializers.py:15: The name tf.tables_initializer is deprecated. Please use tf.compat.v1.tables_initializer instead.
#
# 2021-03-26 13:34:02,324 [WARNING] tensorflow: From /home/vpraveen/.cache/dazel/_dazel_vpraveen/216c8b41e526c3295d3b802489ac2034/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/common/graph/initializers.py:15: The name tf.tables_initializer is deprecated. Please use tf.compat.v1.tables_initializer instead.
#
# WARNING:tensorflow:From /home/vpraveen/.cache/dazel/_dazel_vpraveen/216c8b41e526c3295d3b802489ac2034/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/common/graph/initializers.py:16: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# 2021-03-26 13:34:02,324 [WARNING] tensorflow: From /home/vpraveen/.cache/dazel/_dazel_vpraveen/216c8b41e526c3295d3b802489ac2034/execroot/ai_infra/bazel-out/k8-fastbuild/bin/magnet/packages/iva/build_wheel.runfiles/ai_infra/iva/detectnet_v2/common/graph/initializers.py:16: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
#   0%|                                                  | 0/1506 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/iva/augment/build_augmentor.py:504: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# 2021-03-26 13:34:02.425272: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-03-26 13:34:03.702829: I tensorflow/core/kernels/cuda_solvers.cc:159] Creating CudaSolver handles for stream 0x2f40420
# 2021-03-26 13:34:03.703385: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.11
# 2021-03-26 13:34:05.213313: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 100%|███████████████████████████████████████| 1506/1506 [00:27<00:00, 54.14it/s]

# %% [markdown]
# ## Visualize augmented results <a class="anchor" id="head-3"></a>
# Now that the dataset has been augmented, it is worthwhile to render the augmented images and labels.
# The outputs of `tlt-augment` are generated in the following paths:
# * images: `$USER_EXPERIMENT_DIR/augmented_dataset/images`
# * labels: `$USER_EXPERIMENT_DIR/augmented_dataset/labels`

# %%
# Simple grid visualizer
# %matplotlib inline
import matplotlib.pyplot as plt
import os
from math import ceil
valid_image_ext = ['.jpg', '.png', '.jpeg', '.ppm']

def visualize_images(image_dir, num_cols=4, num_images=10):
    output_path = os.path.join(os.environ['USER_EXPERIMENT_DIR'], image_dir)
    num_rows = int(ceil(float(num_images) / float(num_cols)))
    f, axarr = plt.subplots(num_rows, num_cols, figsize=[80,30])
    f.tight_layout()
    a = [os.path.join(output_path, image) for image in os.listdir(output_path) 
         if os.path.splitext(image)[1].lower() in valid_image_ext]
    for idx, img_path in enumerate(a[:num_images]):
        col_id = idx % num_cols
        row_id = idx // num_cols
        img = plt.imread(img_path)
        axarr[row_id, col_id].imshow(img)

# %%
# Visualizing the first 12 images.
OUTPUT_PATH = 'geometridae_augmented/images' # relative path from $USER_EXPERIMENT_DIR.
COLS = 4 # number of columns in the visualizer grid.
IMAGES = 12 # number of images to visualize.

visualize_images(OUTPUT_PATH, num_cols=COLS, num_images=IMAGES)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-01b5c63836c5> in <module>
#       4 IMAGES = 12 # number of images to visualize.
#       5
# ----> 6 visualize_images(OUTPUT_PATH, num_cols=COLS, num_images=IMAGES)
#
# <ipython-input-18-b283c80fbdeb> in visualize_images(image_dir, num_cols, num_images)
#      11     f, axarr = plt.subplots(num_rows, num_cols, figsize=[80,30])
#      12     f.tight_layout()
# ---> 13     a = [os.path.join(output_path, image) for image in os.listdir(output_path)
#      14          if os.path.splitext(image)[1].lower() in valid_image_ext]
#      15     for idx, img_path in enumerate(a[:num_images]):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/workspace/tlt-experiments/insect-thesis/geometridae_augmented/images'
